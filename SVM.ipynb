# %% [markdown]
# # SVM

# %%
import time
import datetime
import bz2

from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('data_ML_19_05.csv', index_col=['date'], parse_dates=['date'], dayfirst=True)
df.head()
# Out:
#               close  close_change      open      high       low     volume  \
# date
# 2015-01-19  1.15947             1  1.190209  1.192707  1.183859  125293.70
# 2015-06-08  1.12800             1  1.109748  1.115922  1.103201  178572.05
# 2015-06-09  1.12926             1  1.108914  1.115403  1.102083  189387.35
# 2015-06-10  1.13099             1  1.108156  1.115101  1.101890  191876.60
# 2015-06-11  1.12458             0  1.108085  1.115129  1.102208  190246.55
#
#               bb_bbh    bb_bbl    bb_bbm    ATR_10  ...   ROCI_40   ROCI_60  \
# date                                                ...
# 2015-01-19  1.224872  1.182937  1.203905  0.005052  ...  0.000000  0.000000
# 2015-06-08  1.148248  1.085201  1.116725  0.011961  ...  3.059706  3.102878
# 2015-06-09  1.147392  1.085082  1.116237  0.012098  ...  2.952450  3.084663
# 2015-06-10  1.146536  1.084730  1.115633  0.012210  ...  2.897022  3.109756
# 2015-06-11  1.145869  1.084101  1.114985  0.012281  ...  2.946539  3.079194
#
#             ROCI_120  Vortex_diff  Vortex_neg  Vortex_pos  ichimoku_a  \
# date
# 2015-01-19  0.000000    -0.292063    0.566607    0.274544    1.199552
# 2015-06-08 -6.589708     0.134893    0.930980    1.065874    1.113431
# 2015-06-09 -6.401610     0.114822    0.941023    1.055845    1.113217
# 2015-06-10 -6.191681     0.093968    0.952233    1.046201    1.113011
# 2015-06-11 -5.817274     0.076014    0.961502    1.037516    1.112856
#
#             ichimoku_b  ichimoku_bl  ichimoku_cl
# date
# 2015-01-19    1.202186     1.202186     1.196918
# 2015-06-08    1.099360     1.111859     1.115003
# 2015-06-09    1.099360     1.112258     1.114176
# 2015-06-10    1.099360     1.112656     1.113366
# 2015-06-11    1.099360     1.113054     1.112659
#
# [5 rows x 26 columns]

# %%
train_part = int(len(df.close)*0.8)
test_part = len(df.close) - train_part
test_part
# Out:
# 373

# %%
X_train = df.copy(deep=True)
X_train.drop(['close_change', 'close'],axis=1, inplace= True)
X_train.drop(X_train.index[-test_part:],inplace= True)
X_train = StandardScaler().fit_transform(X_train)

X_test = df.copy(deep=True)
X_test.drop(['close_change', 'close'],axis=1, inplace= True)
X_test.drop(X_test.index[:-test_part],inplace= True)
X_test = StandardScaler().fit_transform(X_test)

# %%
y_train =  df['close_change'][:-test_part]
y_test = df['close_change'][-test_part:].to_numpy()

# %%
C_list =  [100, 50, 20, 10, 5, 2, 1, 0.5, 0.3, 0.2, 0.1, 0.01 , 0.005 ,0.001]
kernel_list= ['linear', 'poly', 'rbf', 'sigmoid' ]
scores = []
best_mode = None
best_score = 0
for C in C_list:
    for kernel in kernel_list:
        start_time = datetime.datetime.now()

        print("\nC is:", C, "kernel", kernel)
        model = SVC(C=C, kernel=kernel, random_state=241)
        #verbose=True

        model.fit(X_train, y_train)
        model.predict(X_test)

        scores.append(cross_val_score(estimator=model, X=X_train,y=y_train,scoring="roc_auc"))

        print("score", model.score(X_train, y_train))

        print("Time've passed", datetime.datetime.now() - start_time)
        print("Kross validation score=", scores[-1])
        print("Mean=", np.mean(scores[-1]))

        if np.mean(scores[-1]) > best_score:
            best_model = model
            best_score = np.mean(scores[-1])
# Out:
# C is: 100 kernel linear
# score 0.6102150537634409
# Time've passed 0:00:20.900029
# Kross validation score= [0.59305312 0.53369369 0.44301802 0.55419501 0.68444444]
# Mean= 0.5616808565559748
#
# C is: 100 kernel poly
# score 0.6216397849462365
# Time've passed 0:00:02.330004
# Kross validation score= [0.54119926 0.40472973 0.34027027 0.37931973 0.50022676]
# Mean= 0.4331491492844378
#
# C is: 100 kernel rbf
# score 0.6411290322580645
# Time've passed 0:00:01.260001
# Kross validation score= [0.46371131 0.40761261 0.38869369 0.41814059 0.50176871]
# Mean= 0.4359853831395932
#
# C is: 100 kernel sigmoid
# score 0.4959677419354839
# Time've passed 0:00:00.560001
# Kross validation score= [0.56115691 0.49441441 0.53373874 0.36870748 0.59251701]
# Mean= 0.5101069112090872
#
# C is: 50 kernel linear
# score 0.5934139784946236
# Time've passed 0:00:10.101014
# Kross validation score= [0.58142992 0.5304955  0.42617117 0.52548753 0.65945578]
# Mean= 0.5446079800573651
#
# C is: 50 kernel poly
# score 0.6115591397849462
# Time've passed 0:00:01.580003
# Kross validation score= [0.52403478 0.37761261 0.34108108 0.36748299 0.49256236]
# Mean= 0.42055476492846405
#
# C is: 50 kernel rbf
# score 0.6256720430107527
# Time've passed 0:00:01.070001
# Kross validation score= [0.46064784 0.40022523 0.37977477 0.40834467 0.48244898]
# Mean= 0.4262882972173417
#
# C is: 50 kernel sigmoid
# score 0.4959677419354839
# Time've passed 0:00:00.530001
# Kross validation score= [0.56106681 0.49441441 0.53387387 0.36952381 0.59954649]
# Mean= 0.5116850787806323
#
# C is: 20 kernel linear
# score 0.5725806451612904
# Time've passed 0:00:04.310006
# Kross validation score= [0.54385728 0.51288288 0.40481982 0.48580499 0.62099773]
# Mean= 0.513672540360336
#
# C is: 20 kernel poly
# score 0.5907258064516129
# Time've passed 0:00:01.000001
# Kross validation score= [0.49551741 0.37216216 0.35373874 0.34739229 0.45070295]
# Mean= 0.40390271025181146
#
# C is: 20 kernel rbf
# score 0.6229838709677419
# Time've passed 0:00:00.950002
# Kross validation score= [0.47402802 0.38135135 0.37720721 0.40530612 0.46335601]
# Mean= 0.42024974237651624
#
# C is: 20 kernel sigmoid
# score 0.49798387096774194
# Time've passed 0:00:00.550000
# Kross validation score= [0.56183268 0.49297297 0.60234234 0.3693424  0.58984127]
# Mean= 0.5232663337753214
#
# C is: 10 kernel linear
# score 0.5463709677419355
# Time've passed 0:00:02.210003
# Kross validation score= [0.5246655  0.50130631 0.39085586 0.44666667 0.58575964]
# Mean= 0.48985079227084904
#
# C is: 10 kernel poly
# score 0.5739247311827957
# Time've passed 0:00:00.820002
# Kross validation score= [0.48047033 0.37792793 0.3818018  0.33764172 0.43981859]
# Mean= 0.40353207620378856
#
# C is: 10 kernel rbf
# score 0.6008064516129032
# Time've passed 0:00:00.890001
# Kross validation score= [0.47091949 0.37702703 0.38540541 0.39442177 0.44163265]
# Mean= 0.4138812695652809
#
# C is: 10 kernel sigmoid
# score 0.4959677419354839
# Time've passed 0:00:00.570001
# Kross validation score= [0.56142722 0.49310811 0.53382883 0.37056689 0.59487528]
# Mean= 0.5107612667404531
#
# C is: 5 kernel linear
# score 0.5356182795698925
# Time've passed 0:00:01.370002
# Kross validation score= [0.51078975 0.47599099 0.38558559 0.41337868 0.57460317]
# Mean= 0.4720696364698257
#
# C is: 5 kernel poly
# score 0.5759408602150538
# Time've passed 0:00:00.720001
# Kross validation score= [0.48362391 0.37734234 0.39635135 0.33124717 0.47210884]
# Mean= 0.4121347231810808
#
# C is: 5 kernel rbf
# score 0.5887096774193549
# Time've passed 0:00:00.870001
# Kross validation score= [0.46339595 0.37418919 0.38783784 0.37750567 0.41664399]
# Mean= 0.40391452825984525
#
# C is: 5 kernel sigmoid
# score 0.4952956989247312
# Time've passed 0:00:00.590001
# Kross validation score= [0.56142722 0.48896396 0.53396396 0.36204082 0.59519274]
# Mean= 0.5083177415826423
#
# C is: 2 kernel linear
# score 0.5396505376344086
# Time've passed 0:00:00.900001
# Kross validation score= [0.51371807 0.46243243 0.37292793 0.38657596 0.5644898 ]
# Mean= 0.46002883800140193
#
# C is: 2 kernel poly
# score 0.5564516129032258
# Time've passed 0:00:00.650001
# Kross validation score= [0.46524305 0.3772973  0.39099099 0.32920635 0.43854875]
# Mean= 0.4002572882383668
#
# C is: 2 kernel rbf
# score 0.5786290322580645
# Time've passed 0:00:00.850001
# Kross validation score= [0.45042123 0.35585586 0.39103604 0.35188209 0.40136054]
# Mean= 0.39011115007425323
#
# C is: 2 kernel sigmoid
# score 0.4952956989247312
# Time've passed 0:00:00.620001
# Kross validation score= [0.56498626 0.46243243 0.54184685 0.36358277 0.58993197]
# Mean= 0.5045560555825457
#
# C is: 1 kernel linear
# score 0.5356182795698925
# Time've passed 0:00:00.721001
# Kross validation score= [0.50515835 0.45144144 0.36743243 0.37986395 0.55206349]
# Mean= 0.4511919332496438
#
# C is: 1 kernel poly
# score 0.5463709677419355
# Time've passed 0:00:00.590001
# Kross validation score= [0.4571789  0.37045045 0.39081081 0.33646259 0.43714286]
# Mean= 0.39840912029748365
#
# C is: 1 kernel rbf
# score 0.5524193548387096
# Time've passed 0:00:00.850001
# Kross validation score= [0.45650313 0.35058559 0.38774775 0.35809524 0.38920635]
# Mean= 0.3884276103377333
#
# C is: 1 kernel sigmoid
# score 0.48118279569892475
# Time've passed 0:00:00.590001
# Kross validation score= [0.53205388 0.46121622 0.58743243 0.38793651 0.59297052]
# Mean= 0.5123219118564435
#
# C is: 0.5 kernel linear
# score 0.5329301075268817
# Time've passed 0:00:00.620001
# Kross validation score= [0.49628328 0.43626126 0.36581081 0.38321995 0.56018141]
# Mean= 0.44835134282816397
#
# C is: 0.5 kernel poly
# score 0.5376344086021505
# Time've passed 0:00:00.580000
# Kross validation score= [0.4653782  0.39576577 0.39396396 0.34866213 0.44526077]
# Mean= 0.4098061672971796
#
# C is: 0.5 kernel rbf
# score 0.5524193548387096
# Time've passed 0:00:00.840002
# Kross validation score= [0.45654818 0.3504955  0.37414414 0.36793651 0.37750567]
# Mean= 0.38532599973943393
#
# C is: 0.5 kernel sigmoid
# score 0.4798387096774194
# Time've passed 0:00:00.630000
# Kross validation score= [0.53417128 0.47914414 0.57900901 0.40362812 0.59487528]
# Mean= 0.5181655677843
#
# C is: 0.3 kernel linear
# score 0.5295698924731183
# Time've passed 0:00:00.570001
# Kross validation score= [0.49614813 0.4395045  0.36427928 0.38068027 0.56380952]
# Mean= 0.4488843415655147
#
# C is: 0.3 kernel poly
# score 0.5383064516129032
# Time've passed 0:00:00.570001
# Kross validation score= [0.47366761 0.41923423 0.3981982  0.35664399 0.4338322 ]
# Mean= 0.4163152471298167
#
# C is: 0.3 kernel rbf
# score 0.5416666666666666
# Time've passed 0:00:00.850001
# Kross validation score= [0.46398162 0.35189189 0.36698198 0.37156463 0.37750567]
# Mean= 0.38638515755923514
#
# C is: 0.3 kernel sigmoid
# score 0.4838709677419355
# Time've passed 0:00:00.680001
# Kross validation score= [0.53038699 0.47608108 0.54887387 0.39936508 0.59278912]
# Mean= 0.5094992278398144
#
# C is: 0.2 kernel linear
# score 0.5288978494623656
# Time've passed 0:00:00.540001
# Kross validation score= [0.49326486 0.4327027  0.3677027  0.37628118 0.56517007]
# Mean= 0.4470243016364114
#
# C is: 0.2 kernel poly
# score 0.5329301075268817
# Time've passed 0:00:00.570001
# Kross validation score= [0.48146146 0.43626126 0.39792793 0.35746032 0.43818594]
# Mean= 0.4222593812896556
#
# C is: 0.2 kernel rbf
# score 0.5336021505376344
# Time've passed 0:00:00.850001
# Kross validation score= [0.45298914 0.35265766 0.3645045  0.37297052 0.37664399]
# Mean= 0.3839531634621512
#
# C is: 0.2 kernel sigmoid
# score 0.49126344086021506
# Time've passed 0:00:00.740001
# Kross validation score= [0.52745867 0.49684685 0.495      0.39605442 0.58907029]
# Mean= 0.5008860457971149
#
# C is: 0.1 kernel linear
# score 0.5228494623655914
# Time've passed 0:00:00.500001
# Kross validation score= [0.48470514 0.42986486 0.37018018 0.38222222 0.57564626]
# Mean= 0.44852373322098965
#
# C is: 0.1 kernel poly
# score 0.5342741935483871
# Time've passed 0:00:00.560000
# Kross validation score= [0.50002253 0.48247748 0.39355856 0.37591837 0.47977324]
# Mean= 0.44635003431597564
#
# C is: 0.1 kernel rbf
# score 0.5416666666666666
# Time've passed 0:00:00.860002
# Kross validation score= [0.44623147 0.35414414 0.36522523 0.35029478 0.37655329]
# Mean= 0.37848978293065333
#
# C is: 0.1 kernel sigmoid
# score 0.5047043010752689
# Time've passed 0:00:00.800001
# Kross validation score= [0.44560076 0.49396396 0.42175676 0.43460317 0.59800454]
# Mean= 0.47878583746606446
#
# C is: 0.01 kernel linear
# score 0.5181451612903226
# Time've passed 0:00:00.470000
# Kross validation score= [0.48565121 0.44418919 0.36693694 0.37863946 0.55560091]
# Mean= 0.4462035406131905
#
# C is: 0.01 kernel poly
# score 0.5235215053763441
# Time've passed 0:00:00.560001
# Kross validation score= [0.51772762 0.52864865 0.39702703 0.34929705 0.52276644]
# Mean= 0.46309335771776644
#
# C is: 0.01 kernel rbf
# score 0.5047043010752689
# Time've passed 0:00:00.870001
# Kross validation score= [0.44632157 0.35418919 0.37148649 0.34566893 0.37673469]
# Mean= 0.3788801757562401
#
# C is: 0.01 kernel sigmoid
# score 0.5047043010752689
# Time've passed 0:00:00.810002
# Kross validation score= [0.44591611 0.47211712 0.36711712 0.36975057 0.55659864]
# Mean= 0.4422999110747455
#
# C is: 0.005 kernel linear
# score 0.5248655913978495
# Time've passed 0:00:00.470000
# Kross validation score= [0.48650719 0.45045045 0.36918919 0.37451247 0.55768707]
# Mean= 0.4476692743561239
#
# C is: 0.005 kernel poly
# score 0.5134408602150538
# Time've passed 0:00:00.560001
# Kross validation score= [0.51475425 0.52887387 0.39126126 0.34675737 0.52226757]
# Mean= 0.46078286490301623
#
# C is: 0.005 kernel rbf
# score 0.5047043010752689
# Time've passed 0:00:00.870001
# Kross validation score= [0.44632157 0.35427928 0.37148649 0.34566893 0.37673469]
# Mean= 0.3788981937742581
#
# C is: 0.005 kernel sigmoid
# score 0.5047043010752689
# Time've passed 0:00:00.800001
# Kross validation score= [0.44591611 0.47211712 0.36711712 0.36975057 0.55659864]
# Mean= 0.4422999110747455
#
# C is: 0.001 kernel linear
# score 0.5047043010752689
# Time've passed 0:00:00.470001
# Kross validation score= [0.46709015 0.45238739 0.36945946 0.3200907  0.55287982]
# Mean= 0.43238150314120044
#
# C is: 0.001 kernel poly
# score 0.5047043010752689
# Time've passed 0:00:00.570001
# Kross validation score= [0.51475425 0.52905405 0.37355856 0.34675737 0.52263039]
# Mean= 0.4573509227567884
#
# C is: 0.001 kernel rbf
# score 0.5047043010752689
# Time've passed 0:00:00.870001
# Kross validation score= [0.44645673 0.35418919 0.37148649 0.34548753 0.37668934]
# Mean= 0.3788618549621388
#
# C is: 0.001 kernel sigmoid
# score 0.5047043010752689
# Time've passed 0:00:00.810001
# Kross validation score= [0.44438438 0.47211712 0.36693694 0.36975057 0.55632653]
# Mean= 0.4419031055653573
